# %% [markdown]
# ### Python Day Two Task
# #### (List,Tuples,Sets,Dictionaries)

# %%
# LIST
myList = ['apple','orange','mango','banana','apple']
print(myList)
print(len(myList))

#List Datatype:
list1 = ['apple','mango','cherry']
list2 = [1,2,3]
list3 = [True,False,True]
print(list1)
print(list2)
print(list3)

#Different datatype:
list = ['ahsan','ali',32,True,'male']
print(list)

#Access List Items:
myList = ['ahsan','ali',32,True,'male','sher',21, 70, 'zeeshan',45,61]
print(myList[5])
print(myList[-6])
print(myList[4:8])
print(myList[2:])
print(myList[:8])
print(myList[-6:-2])

#check if item exist:
thislist = ['ali','sher','mango','orange']
if 'ali' in thislist:
    print('yes', 'this item exists in list')

#Change List items:
thislist = ['orange','mango','banana','apple','lemon','grapes']
thislist[2] = 'peech'
print(thislist)

thislist[1:3] = ['watermelon','peech']
print(thislist)

#insert item:
thislist = ['apple','mango','orange']
thislist.insert(2,'cherry')
print(thislist)

#append item:
thislist = ['red','purple','blue']
thislist.append('blue')
print(thislist)

#extend item:
thislist = ['red','green','black']
mainly = ['white','pink','yellow']
thislist.extend(mainly)
print(thislist)

#remove items:
thislist = ['apple','mango','banana']
thislist.remove('mango')
print(thislist)

#pop item
thislist = ['apple','mango','banana']
thislist.pop(2)
print(thislist)

#del item
myList = ['red','purple','blue','orange']
del myList[1]
print(myList)

#clear item
myList =['orange','mango','banana','apple','lemon','grapes']
myList.clear()
print(myList)

#Loop List
months = ['jan','feb','mar']
for month in months:
    print(month)

#range in loop
myList = ['apple','mango','orange']
for i in range(len(myList)):
    print(myList[i])

#list comprehension
fruits = ['apple','mango','banana','orange']
newList = [x for x in fruits if 'a' in x]
new_list = [x.upper() for x in fruits]
new_lists = [x if x != 'banana' else 'orange' for x in fruits]
print(newList)
print(new_list)
print(new_lists)

#range comprehension
newList = [x for x in range (10) if x<5]
print(newList)

#list sort
myList = ['ahsan','zeeshan','ali','shahbaz']
myList.sort(reverse=True)
print(myList)

#list copy
myList = ['ali','hamza','omer','bakar']
myList.copy()
print(myList)

#join List
list1 = ['ahsan','ijaz','ali','touseef']
list = [1,2,3,4,5]
for lists in list:
    list1.append(lists)
print(list1)
# Out:
# ['apple', 'orange', 'mango', 'banana', 'apple']
# 5
# ['apple', 'mango', 'cherry']
# [1, 2, 3]
# [True, False, True]
# ['ahsan', 'ali', 32, True, 'male']
# sher
# sher
# ['male', 'sher', 21, 70]
# [32, True, 'male', 'sher', 21, 70, 'zeeshan', 45, 61]
# ['ahsan', 'ali', 32, True, 'male', 'sher', 21, 70]
# ['sher', 21, 70, 'zeeshan']
# yes this item exists in list
# ['orange', 'mango', 'peech', 'apple', 'lemon', 'grapes']
# ['orange', 'watermelon', 'peech', 'apple', 'lemon', 'grapes']
# ['apple', 'mango', 'cherry', 'orange']
# ['red', 'purple', 'blue', 'blue']
# ['red', 'green', 'black', 'white', 'pink', 'yellow']
# ['apple', 'banana']
# ['apple', 'mango']
# ['red', 'blue', 'orange']
# []
# jan
# feb
# mar
# apple
# mango
# orange
# ['apple', 'mango', 'banana', 'orange']
# ['APPLE', 'MANGO', 'BANANA', 'ORANGE']
# ['apple', 'mango', 'orange', 'orange']
# [0, 1, 2, 3, 4]
# ['zeeshan', 'shahbaz', 'ali', 'ahsan']
# ['ali', 'hamza', 'omer', 'bakar']
# ...

# %%
#Tuples

#Access tuple:
thistuple = ('mango','kiwi','banana','orange','melon','apple','cherry')
print(thistuple[-4:-1])

thistuple = ('mango','kiwi','banana','orange','melon','apple','cherry')
print(thistuple[:-4])

#Update tuple:
x = ('kiwi','apple','mango')
y = list(x)
y[1] ='pineapple' 
print(y)

#add elements:
thistuple =('yellow','red','orange','purple','pink')
y = list(thistuple)
y.append('colors')
thistuple = tuple(y)
print(thistuple)

#remove tuple:
# thistuple= ('yellow','red','orange','purple','pink')
# y = list(thistuple)
# y.remove('purple')
# thistuple = tuple(y)
# print(thistuple)

#del tuple:
thistuple = ('mango','banana','orange')
# del thistuple
print(thistuple)

#Unpack tuple:
fruits = ('apple','mango','orange')
(green,orange,purple) = fruits
print(green)
print(orange)
print(purple)

fruits = ('apple','mango','orange','greeno','yellowish','white')
(green,yellow,*red) = fruits
print(green)
print(yellow)
print(red)

#loop tuple:
thistuple = ('apple','mango','orange')
for x in thistuple:
    print(x)

thistuple = ('apple','mango','banana')
for i in range(len(thistuple)):
    print(thistuple[i])

thistuple = ('red','yellow','purple')
i = 0
while i < len(thistuple):
    i = i + 1
print(thistuple)
# Out:
# ('orange', 'melon', 'apple')
# ('mango', 'kiwi', 'banana')
# ['kiwi', 'pineapple', 'mango']
# ('yellow', 'red', 'orange', 'purple', 'pink', 'colors')
# ('mango', 'banana', 'orange')
# apple
# mango
# orange
# apple
# mango
# ['orange', 'greeno', 'yellowish', 'white']
# apple
# mango
# orange
# apple
# mango
# banana
# ('red', 'yellow', 'purple')

# %%
#Sets
thissets = {'apple','orange','mango'}
print(thissets)

thissets = {'red','blue','white','green','red'}   #duplicates not allowed
print(thissets)

thissets = {'kiwi','banana','orange','mango',True,1,2,0,False}
print(thissets)

set1 = {'apple','orange','mango'}
set2 = {1,2,3,4,1,2}
set3 = {True,False,True}
print(set1)
print(set2)
print(set3)
print(type(set1))

#Access Set
thissets = {'apple','cherry','banana'}
for x in thissets:
    print(x)

thissets = {'red','yellow','orange'}
print('red' in thissets)

thissets = {'red','yellow','orange'}
print('redd' not in thissets)

#Add set items
thisset = {'red','yellow','orange','white'}
thisset.add('black')
print('thisset')

thissets = {'red','blue','green'}
tropical ={'white','yellow','purple'}

thissets.update(tropical)
print(thissets)

thissets = {'blue','red','white'}
myList = ['black','orange']
thissets.update(myList)
print(thissets)

#Remove set items
thissets = {'blue','red','white'}
thissets.remove('red')
print(thissets)

thissets = {'blue','red','white'}
thissets.discard('white')
print(thissets)

thissets = {'blue','red','white'}
x = thissets.pop()
print(x)
print(thissets)

#loop set
thissets = {'blue','red','white'}
for x in thissets:
    print(x)

#Join set      (union,update)
set1 ={'a','b','c'}
set2 = {1,2,3}
set3 = set1.union(set2)
print(set3)

set1 ={'a','b','c','d'}
set2 = {1,2,3}
set3 = set1 | set2
print(set3)

set1 ={'a','b','c'}
set2 = {1,2,3}
set3 = {'john','cena'}
set4 = {'apple','orange','mango'}
myset = set1.union(set2,set3,set4)
print(myset)

set1 ={'a','b','c'}
set2 = {1,2,3}
set3 = {'john','cena'}
set4 = {'apple','orange','mango'}
myset = set1|set2|set3|set4
print(myset)

x ={'apple','orange','mango'}
y = (1,2,3)
z = x.union(y)
print(x)

set1 ={'apple','orange','mango'}
set2 = (1,2,3)
set1.update(set2)
print(set1)

#Intersection   
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1.intersection(set2)
print(set3)

set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}
set3 = set1 & set2
print(set3)

set1 = {'apple','orange',1,'mango',0}
set2 = {False,'google','mango',True}
set3 = set1.intersection(set2)
print(set3)

#Difference
set1 = {"apple", "banana", "cherry",'kiwi'}
set2 = {"google", "cherry", "apple",'pine'}
set3 = set1.difference(set2)
print(set3)

set1 = {"apple", "banana", "cherry",'kiwi'}
set2 = {"google", "cherry", "apple",'pine'}
set3 = set2-set1
print(set3)

#Symmetric Differences
set1 = {'apple','mango','orange','kiwi'}
set2 = {'cherry','mangoos','ananas','apple'}
set3 = set1.symmetric_difference(set2)
print(set3)

set1 = {'apple','mango','orange','kiwi'}
set2 = {'cherry','mangoos','ananas','apple'}
set3 = set1 ^ set2
print(set3)

set1 = {'apple','mango','orange','kiwi'}
set2 = {'apple','ananas','kiwi','pine'}
set1.symmetric_difference_update(set2)
print(set1)
# Out:
# {'apple', 'orange', 'mango'}
# {'red', 'white', 'green', 'blue'}
# {0, True, 2, 'mango', 'orange', 'kiwi', 'banana'}
# {'apple', 'orange', 'mango'}
# {1, 2, 3, 4}
# {False, True}
# <class 'set'>
# apple
# banana
# cherry
# True
# True
# thisset
# {'blue', 'purple', 'red', 'white', 'green', 'yellow'}
# {'blue', 'red', 'orange', 'white', 'black'}
# {'white', 'blue'}
# {'red', 'blue'}
# red
# {'white', 'blue'}
# red
# white
# blue
# {'a', 1, 'b', 2, 3, 'c'}
# {'a', 1, 'b', 'd', 2, 3, 'c'}
# {1, 2, 3, 'mango', 'apple', 'c', 'a', 'orange', 'b', 'john', 'cena'}
# {1, 2, 3, 'mango', 'apple', 'c', 'a', 'orange', 'b', 'john', 'cena'}
# {'apple', 'orange', 'mango'}
# {1, 2, 'mango', 3, 'apple', 'orange'}
# {'apple'}
# {'apple'}
# {False, True, 'mango'}
# {'kiwi', 'banana'}
# {'pine', 'google'}
# {'mango', 'cherry', 'mangoos', 'orange', 'ananas', 'kiwi'}
# {'mango', 'cherry', 'mangoos', 'orange', 'ananas', 'kiwi'}
# {'pine', 'mango', 'orange', 'ananas'}

# %%
#Python Dictionaries
thisdict = {
    "brand" : "Ford",
    "model": "Musthag",
    "year": '2016'
}
print(thisdict)

thisdict = {         #override the first year
    'brand' : 'toyota',
    'model' : 'Honda',
    'year': '2016',
    'year':'2018'
}
print(thisdict)
print(len(thisdict))

thisdict = {
    'brand':'Ford',
    'electric':False,
    'year':  1999,
    'colors':['white','red','blue']
    }
print(thisdict)

thisdict = dict(name = 'ahsan',age = 36, country = 'Norway')
print(thisdict)

car = {
    'brand':'Ford',
    'model' : 'Mustang',
    'year':2019
}
x = car.keys()
print(x)
car['color'] = 'white'
print(x)


car = {
    'brand':'Ford',
    'model' : 'Mustang',
    'year':2019
}
x = car.values()
print(x)
car['color'] = 'red'
print(x)

car = {
    'brand':'Ford',
    'model' : 'Mustang',
    'year':2019
}
x = car.items()
print(x)
car['color'] = 'red'
print(x)

mydict = {
    'brand':'civic',
    'model': 'Honda',
    'year': 2019
}
if 'model' in mydict:
    print("yes,it  is one of the keys in this dictionary")
else:
    print('It is not in the key')

#change item dict
person = {
    'name' : 'Ahsan',
    'age':24,
    'location': 'Islamabad'
}
person['age'] = 26
print(person)

person = {
    'name' : 'Ahsan',
    'age':24,
    'location': 'Islamabad'
}
person.update({'location':'karachi'})
print(person)

#Remove items
car = {
'model':'Honda',
'brand':'cultus',
'year':2018
}
car.popitem()
print(car)

car = {
'model':'Honda',
'brand':'cultus',
'year':2018
}
car.clear()
print(car)

#Loop dict
country = {
    'name' : 'Pakistan',
    'city': 'Islamabad',
    'year': 1995
}
for x in country.items():
    print(x)

#copy dict
country = {
    'name' : 'Pakistan',
    'city': 'Islamabad',
    'year': 1995
}
mycountry = country.copy()
print(mycountry)

car = {
    'model':'mehran',
    'brand': 'suzuki',
    'year':2000
}
mycar = dict(car)
print(mycar)

#Nested loop
school1={
    'name':'IMCB g9',
    'year': 2001
}
school2={
    'name':'IMCB g10',
    'year': 2002
}
school3= {
    'name':'IMCB g11',
    'year':2003
}

myschools = {
    "myschool1" : school1,
    "myschool2": school2,
    "myschool3" : school3

}
print(myschools['myschool2']['year'])

for x,obj in myschools.items():
    print(x)
    for y in obj:
        print(y + ':',obj[y])
# Out:
# {'brand': 'Ford', 'model': 'Musthag', 'year': '2016'}
# {'brand': 'toyota', 'model': 'Honda', 'year': '2018'}
# 3
# {'brand': 'Ford', 'electric': False, 'year': 1999, 'colors': ['white', 'red', 'blue']}
# {'name': 'ahsan', 'age': 36, 'country': 'Norway'}
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])
# dict_values(['Ford', 'Mustang', 2019])
# dict_values(['Ford', 'Mustang', 2019, 'red'])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2019)])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2019), ('color', 'red')])
# yes,it  is one of the keys in this dictionary
# {'name': 'Ahsan', 'age': 26, 'location': 'Islamabad'}
# {'name': 'Ahsan', 'age': 24, 'location': 'karachi'}
# {'model': 'Honda', 'brand': 'cultus'}
# {}
# ('name', 'Pakistan')
# ('city', 'Islamabad')
# ('year', 1995)
# {'name': 'Pakistan', 'city': 'Islamabad', 'year': 1995}
# {'model': 'mehran', 'brand': 'suzuki', 'year': 2000}
# 2002
# myschool1
# ...
